# %% [markdown]
# <a href="https://colab.research.google.com/github/anacarolinaz/portfolio/blob/main/draft_aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/pesquet-image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7FB6A838D510>

# %%
#converter RGB - Grayscale (Escala de cinza)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7FB6A839FB10>
